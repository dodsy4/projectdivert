# %%
import pandas as pd
from math import sin, cos, sqrt, atan2,radians

# %%
df = pd.read_csv('data/charities')

# %%
df.head()
# Out:
#    Unnamed: 0 sup_type              name  \
# 0         307  Charity  Emmaus Greenwich
# 1         323  Charity    Forces Support
# 2         324  Charity        Furnistore
# 3         325  Charity   Help for Heroes
# 4         326  Charity           D.A.D.S
#
#                                       address_street           city  postcode  \
# 0  Emmaus Greenwich Charity, 9 Knight's Hill, Wes...         London  SE27 0JD
# 1                                  50-54 High Street         London   CR0 1YB
# 2                              34 Holmethorpe Avenue        Redhill   RH1 2NL
# 3                                     Tedworth House      Wiltshire   SP9 7AJ
# 4                     161-163 Longford Road, Cannock  Staffordshire  WS11 0LF
#
#          lat      long                            website  \
# 0  51.431235 -0.104498  https://www.emmaus.org.uk/lambeth
# 1  51.372522 -0.100617                                NaN
# 2  51.249863 -0.157649                                NaN
# 3  51.226805 -1.668053            www.helpforheroes.co.uk
# 4  52.681517 -2.037499                                NaN
#
#                                 email  ...       supplier_contact_email  \
# 0         giorgio@emmausgreenwich.org  ...  giorgio@emmausgreenwich.org
# 1            croydon@forcessupport.uk  ...     croydon@forcessupport.uk
# 2            manager@furnistore.co.uk  ...                          NaN
# 3  lauren.hinton@helpforheroes.org.uk  ...                          NaN
# 4            andy@dadssupported.co.uk  ...                          NaN
#
#   supplier_contact_telephone percent_recyclablenum percent_efwnum  \
# 0                        NaN                 100.0            NaN
# 1                        NaN                 100.0            0.0
# 2                        NaN                 100.0            NaN
# 3                        NaN                 100.0            NaN
# 4                        NaN                   NaN            NaN
#
#    provides_a_rebateyn  supplier_auditislist_yes_no_na  \
# 0                  0.0                             NaN
# 1                  0.0                             NaN
# 2                  0.0                             NaN
# 3                  0.0                             NaN
# 4                  0.0                             NaN
#
#    supplier_audit_date_completed  notes  hierarchy  origin
# 0                            NaN    NaN        NaN     df2
# 1                            NaN    NaN        NaN     df2
# 2                            NaN    NaN        NaN     df2
# 3                            NaN    NaN        NaN     df2
# 4                            NaN    NaN        NaN     df2
#
# [5 rows x 22 columns]

# %%
newlat=39.53
newlon=-119.81



#Distance function between two lat/lon
def getDist(lat1,lon1,lat2,lon2):
  R = 6373.0

  lat1 = radians(lat1)
  lon1 = radians(lon1)
  lat2 = radians(lat2)
  lon2 = radians(lon2)

  dlon = lon2 - lon1
  dlat = lat2 - lat1

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  return R * c

#Apply distance function to dataframe
df['dist']=list(map(lambda k: getDist(df.loc[k]['lat'],df.loc[k]['lon'],newlat,newlon), df.index))

#This will give all locations within radius of 600 km
df[df['dist']<600]
# Out:
#   location    lat     lon        dist
# 2       LV  36.16 -115.14  555.511724
