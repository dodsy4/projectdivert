# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## BlueBox WebApp Scrape

# %%
df = pd.DataFrame({'date': '22/10/2019', 'Site': 'ABC_NN60BQ', 'postcode': 'NN60BQ',
      'material': 'Desk', 'Waste_stream (tonnes)': 4,
      'conventional_route': 'Landfill - Augean Energy & Construction',
      'conventional_cost': 2623, 'conventional_carbon_kgCo2e': 71.4,
      'convetional_social_value_%': 10,
      'project_divert_route': 'Recycling via MRF - Gowing and Pursey',
      'project_divert_cost': 920, 'project_divert_carbon_kgco2e': 119,
      'project_divert_social_value_%': 40, 
      'Reuse_on_site_cost': 0,'Reuse_on_site_saving': 2623,
      'Reuse_on_site_carbon_saving_KG(CO2 eg)': 71.4,
      'Reuse_off_site_cost': 0, 'Reuse_off_site_saving':2623,
      'Reuse_off_site_carbon_saving_KG(CO2_eg)': 71.4,
      'Take_back_scheme_cost': 0, 'Take_back_scheme_saving': '',
      'Take_back_scheme_carbon_saving_KG(CO2_eg)': '',
      'Landfill_cost': '', 'Landfill_saving': '',
      'Landfill_carbon saving_KG(CO2_eg)': '',
      'Recycle_&_reprocess_cost': '', 'Recycle_&_reprocess_saving': '',
      'Recycle_&_reprocess_carbon_saving_KG(CO2_eg)': '',
      'Energy_from_waste_cost': '', 'Energy_from_waste_saving': '',
      'Energy_from_waste_carbon_saving_KG(CO2_eg)': '',
      'Direct_recycle_&_reprocess_cost': '',
      'Direct_recycle_&_reprocess_saving': '',
      'Direct_recycle_&_reprocess_carbon_saving_KG(CO2_eg)': '',
      'Direct_energy_from_waste_cost': 0,
      'Direct_energy_from_waste_saving': '',
      'Direct_energy_from_waste_carbon_saving_KG(CO2_eg)': ''}, index=[0])

# %%
df
# Out:
#          date        Site postcode material  Waste_stream (tonnes)  \
# 0  22/10/2019  ABC_NN60BQ   NN60BQ     Desk                      4
#
#                         conventional_route  conventional_cost  \
# 0  Landfill - Augean Energy & Construction               2623
#
#    conventional_carbon_kgCo2e  convetional_social_value_%  \
# 0                        71.4                          10
#
#                     project_divert_route  ...  \
# 0  Recycling via MRF - Gowing and Pursey  ...
#
#    Recycle_&_reprocess_carbon_saving_KG(CO2_eg)  Energy_from_waste_cost  \
# 0
#
#    Energy_from_waste_saving  Energy_from_waste_carbon_saving_KG(CO2_eg)  \
# 0
#
#    Direct_recycle_&_reprocess_cost  Direct_recycle_&_reprocess_saving  \
# 0
#
#    Direct_recycle_&_reprocess_carbon_saving_KG(CO2_eg)  \
# 0
#
#    Direct_energy_from_waste_cost  Direct_energy_from_waste_saving  \
# 0                              0
#
#    Direct_energy_from_waste_carbon_saving_KG(CO2_eg)
# 0
#
# ...

# %%
list(df.columns)
# Out:
# ['date',
#  'Site',
#  'postcode',
#  'material',
#  'Waste_stream (tonnes)',
#  'conventional_route',
#  'conventional_cost',
#  'conventional_carbon_kgCo2e',
#  'convetional_social_value_%',
#  'project_divert_route',
#  'project_divert_cost',
#  'project_divert_carbon_kgco2e',
#  'project_divert_social_value_%',
#  'Reuse_on_site_cost',
#  'Reuse_on_site_saving',
#  'Reuse_on_site_carbon_saving_KG(CO2 eg)',
#  'Reuse_off_site_cost',
#  'Reuse_off_site_saving',
#  'Reuse_off_site_carbon_saving_KG(CO2_eg)',
#  'Take_back_scheme_cost',
#  'Take_back_scheme_saving',
#  'Take_back_scheme_carbon_saving_KG(CO2_eg)',
#  'Landfill_cost',
#  'Landfill_saving',
#  'Landfill_carbon saving_KG(CO2_eg)',
#  'Recycle_&_reprocess_cost',
#  'Recycle_&_reprocess_saving',
#  'Recycle_&_reprocess_carbon_saving_KG(CO2_eg)',
#  'Energy_from_waste_cost',
#  'Energy_from_waste_saving',
#  'Energy_from_waste_carbon_saving_KG(CO2_eg)',
#  'Direct_recycle_&_reprocess_cost',
# ...

# %%
def add_row(row):
    df_length = len(df)
    df.loc[df_length] = row

# %%
test_tn11xp = ['25/12/2019', 'Test_Site_TN11XP', 'TN11XP',
                    'Doors and Windows', 10, 'Landfill - Stangate Landfill',
                    2578, 29.4, 10, 'Recycling - Hamman Metal',
                    172, 23.1, 30, 0, 2578, 29.4, 0, 2578, 29.4, 0,
                    '', '', 2578, 0, 0, 0, '', '', 0, '', '', 172, 2406,
                    6.3, 0,'', ''
                   ]

add_row(test_tn11xp)

# %%
test_sw1a2et = ['12/12/2019','Test_Site_SW1A2ET', 'SW1A2ET',
                     'Ceiling Tiles', 10, 'Landfill - Tripcock Point Landfill',
                     2579, 25.2, 10, 'Charity - Emmaus Greenwich Community Shop',
                     140, 57.4, 0, 0, 2579, 25.2, 0, 2579, 25.2, 0, '', '',
                     2579, 0, 0, 168, 2411, 6.3, 180, 2399, -6.3, 0, '',
                     '',0,'',''
                    ]

add_row(test_sw1a2et)

# %%
dron_house = ['20/12/2019', 'Dron House', 'E13AB',
              'Metal Doors', 19, 'EFW via MRF - Sharp Skips', 348, 50.4,
              0, 'Charity - QSA Homestore', 152, 62.32, 0, 0, 348, 50.4,
              0, 348, 50.4, 0, '', '', 5146, -4798, 12.6, 324, 24, 25.2,
              348, 0, 0, 468, -120, -126, 0, '', ''
              
             ]

add_row(dron_house)

# %%
unknown_E161DR = ['26/01/2020', 'Unknown_E161DR', 'E161DR',
                  '8 Pallets of Ceiling Tiles', 2,
                 'EFW via MRF - Sharp Skips', 168, 18.9, 40,
                  'Charity - Reclaim (East Thames Group)', 8, 3.28, 100,
                 0, 168, 18.9, 0, 168, 18.9, 0, '', '', 2571,
                 -2403, 2.1, 162, 6, 6.3, 168, 0, 0, 226, -58, -60.9, 0, '', '']

add_row(unknown_E161DR)

# %%
unknown_SN22NA = ['19/02/2020', 'Unknown_SN22NA', 'SN22NA',
                 'Light Fittings', 1, 'EFW via MRF - Sharp Skips', 414,
                 277.2, 40, 'Charity - Epping Forest Reuse', 224, 91.84,
                 100, 0, 414, 277.2, 0, 414, 277.2, 0, '', '', 2766, -2352, 50.4,
                 420, -6, -6.3, 414, 0, 0, 398, 16, 16.8, 0, '', '']

add_row(unknown_SN22NA)

# %%
Oktra_Head_Office_WC1V7PB = ['24/02/2020', 'Oktra_Head_Office', 'WC1V7PB',
                             'Carpet Tiles', 1, 'EFW via MRF - Sharp Skips',
                             180, 31.5, 40, 'Charity - Emmaus Greenwich Community Shop', 14, 5.74,
                             100, 0, 180, 31.5, 0, 180, 31.5, 0, '', '', 2579, -2399, 6.3, 168, 12,
                             12.6, 180, 0, 0, 240, -60, -63, 0, '', '']

add_row(Oktra_Head_Office_WC1V7PB)

# %%
test_WC1A1PB = ['06/03/2020', 'Test_WC1A1PB', 'WC1A1PB',
                '41 x FCUs (fan coil units), original manufacturer was Diffusion', 1,
               'EFW via MRF - Sharp Skips', 182, 33.6, 40, 'Charity - QSA Homestore', 14, 5.74,
               100, 0, 182, 33.6, 0, 182, 33.6, 0, '', '', 2581, -2399, 6.3, 172, 10, 10.5, 182,
               0, 0, 240, -58, -60.9, 0, '', '']

add_row(test_WC1A1PB)

# %%
ISG_SN28UU = ['09/03/2020', 'ISG_SN28UU', 'SN28UU', 'Carpet Tiles', 16,
              'EFW via MRF - Sharp Skips', 788, 512.4, 40, 'Recycling - Hamman Metal',
             752, 474.6, 35, 0, 788, 512.4, 0, 788, 512.4, 0, '', '', 5492, -4704, 100.8,
             788, 0, 0, 788, 0, 0, 752, 36, 37.8, 0, '', '']

add_row(ISG_SN28UU)

# %%
M_Moser_Brighton_BN14DA = ['13/05/2020', 'M_Moser_Brighton_BN14DA', 'BN14DA', 'Clean timber',
                           4, 'EFW via MRF - RTS', 890, 76.5, 40,
                           'Charity - Foodbank The Whitehawk', 890, 1.7, 100, 0, 890, 76.5, 890,
                           0, 74.8, 0, '', '', 890, 0, -6440.8, 890, 0, 0, 890, 0, 0, 890, 0, 61.2,
                           0, '', ''
                          ]

add_row(M_Moser_Brighton_BN14DA)

# %%
Cedar_Court_b_SL43QB = ['30/06/2020', 'Cedar Court (b) SL43QB', 'SL43QB',
                          '10 desks (2nd version)', 2.25, 'EFW via MRF - Gowing and Pursey',
                          150, 13.94, 15, 'Charity - Foodbank Yiewsley & West', 150, 5.74, 45,
                          0, 150, 13.94, 150, 0, 13.12, 150, 0, -12.3, 150, 0, 10.66, 150,
                          0, 0, 150, 0, 0, 150, 0, 12.3, 0, '', '']

add_row(Cedar_Court_b_SL43QB)

# %%
National_Trust_b_SN22NA = ['23/06/2020', 'National Trust_b_SN22NA', 'SN22NA',
                           ' Carpet Tiles (b)', 3, 'Recycling - Hills Waste Solutions',
                          605, 609.14, 35,
                           'Charity - British Heart Foundation- Swindon Furniture & Electrical Shop',
                           605, 0.82, 45, 0, 605, 609.14, 125, 480, 608.32, 605, 0, 591.1, 0, '', '',
                           0, '', '', 0, '', '', 605, 0, 0, 0, '', '']

add_row(National_Trust_b_SN22NA)

# %%
test_N66HQ = ['22/06/2020', 'TEST_N66HQ', 'N66HQ', 'Plasterboard', 2,
              "Recycling via MRF - O'Donovan", 350, 3.28, 40, 'Recycling - PB Donoghue',
             350, 1.64, 35, 0, 350, 3.28, 0, 350, 2.46, 0, '', '', 350, 0, -386.46, 350,
             0, 0, 0, '', '', 350, 0, 1.64, 0, '', '']

add_row(test_N66HQ)

# %%
test_W1B5QQ = ['22/06/2020', 'test_W1B5QQ', 'W1B5QQ', 'WEEE', 1, 'Recycling via MRF - RTS',
              325, 3.28, 40, 'Recycling - Project Divert Test', 325, 1.65, 35, 0, 325, 3.28,
              0, 325, 2.46, 0, '', '', 325, 0, -1.64, 325, 0, 0, 0, '', '', 325, 0, 1.64,
              0, '', '']

add_row(test_W1B5QQ)

# %%
Cedar_Court_SL43QA = ['13/05/2020', 'Cedar_Court_SL43QA', 'SL43QA', 'Desks', 2.25,
                      'Recycling via MRF - Gowing and Pursey', 325, 13.94, 40,
                      'Recycling - Enviro Green', 325, 2.46, 35, 0, 325, 13.94, 0, 325, 13.12,
                     0, '', '', 325, 0, 10.66, 325, 0, 0, 0, '', '', 325, 0, 11.48, 0, '', '']

add_row(Cedar_Court_SL43QA)

# %%
test_W43QT = ['23/06/2020', 'test_W43QT', 'W43QT', 'Ceiling Tiles', 1,
              'Recycling via MRF - Gowing and Pursey', 325, 3.28, 40,
             'Recycling - West 7 Reclamation', 325, 1.64, 35, 0, 325, 3.28, 0, 325, 2.46,
             0, '', '', 325, 0, -2.46, 325, 0, 0, 0, '', '', 325, 0, 1.64, 0, '', '']

add_row(test_W43QT)

# %%
test_S174FY = ['09/03/2020', 'test_S174FY', 'S174FY',  'Test Ceiling Tiles', 13.01,
              'Direct Recycling - Right Lets Shred', 1789.26, 123.9, 35,
               'Direct Recycling - Right Lets Shred', 1789.26, 123.9, 35, 0, 1789.26, 123.9,
               0, 1789.26, 121.8, 0, '', '', 1789.26, 0, 6.3, 0, '', '', 0, '', '',
               1789.26, 0, 0, 0, '', '']

add_row(test_S174FY)

# %%
test_S174FY = ['01/07/2020', 'test_S174FY', 'S174FY', 'Bricks Test', 1,
              'Direct Recycling - Right Lets Shred', 325, 48.38, 35,
              'Direct Recycling - Right Lets Shred', 325, 48.38, 35,
              0, 325, 48.38, 0, 325, 47.56, 0, '', '', 325, 0, 2.46, 0, '', '', 0, '', '',
              325, 0, 0, 0, '', '']

add_row(test_S174FY)

# %%
test_SW1A2ET = ['11/08/2020', 'test_SW1A2ET', 'SW1A2ET', 'Kitchen Appliances', 1,
                'Landfill - Beddington Corner Landfill', 398, 212.06, 10,
                'Direct Recycling - Paper Round', 394, 206.32, 45,
                -1, 399, 6.56, 331, 67, 5.74, -1, '', '', 398, 0, 0, -1, '', '',
                -1, '', '', 394, 4, 5.74, -1, '', '']

add_row(test_SW1A2ET)

# %%
test_N16AT = ['04/11/2020', 'test_N16AT', 'N16AT', 'Bricks', 1,
             'Recycling via MRF - Ace Skip Hire', 325, 260.52, 40,
             'Charity - British Heart Foundation- Book Bank- Paul Street', 360, 243.3, 100,
             0, 325, 17.22, 360, -35, 16.4, 0, '', -26.24, 394, -69, 9.84, 325, 0, 0, 0, '', '',
             360, -35, 16.4, 0, '', '']

add_row(test_N16AT)

# %%
Post_Building_WC1A1AP = ['28/08/2020', 'Post_Building_WC1A1AP', 'WC1A1AP', 'Fridge Freezers',
                        0.15, 'Recycling via MRF - Ace Skip Hire', 325, 591.05, 40,
                        'Charity - British Heart Foundation- Camden Shop', 360, 575.47, 100,
                        0, 325, 16.4, 360, -35, 15.58, 0, '', -26.24, 407.7, -82.7, 9.02,
                        325, 0, 0, 0, '', '', 360, -35, 15.58, 0, '', '']

add_row(Post_Building_WC1A1AP)

# %%
National_Trust_c_NN113SD = ['31/08/2020', 'National_Trust_c_NN113SD', 'NN113SD',
                           'Plate Glass from windows', 1, 
                            'Recycling via MRF - D&M Recycling & Waste Management', 325, 907.56,
                           40, 'Charity - Blakesley Church Of England', 360, 903.46, 100,
                           0, 325, 6.56, 360, -35, 5.74, 0, '', -21.32, 394, -69, -20.5,
                           325, 0, 0, 0, '', '', 360, -35, 0, 0, '', '']

add_row(National_Trust_c_NN113SD)

# %%
Hippodrome_WC2H7JH = ['22/09/2020', 'Hippodrome WC2H7JH', 'WC2H7JH',
                      'Floor Tiles', 1,
                     'Recycling via MRF - Ace Skip Hire', 325, 516.15, 40,
                     'Charity - Acting for Others', 360, 499.75, 100,
                     0, 325, 16.4, 360, -35, 15.58, 0, '', -26.24, 394, -69, 9.02,
                     325, 0, 0, 0 , '', '', 360, -35, 14.76, 0, '', '']

add_row(Hippodrome_WC2H7JH)

# %%
ISG_UB69PF = ['16/11/2020', 'ISG_UB69PF', 'UB69PF', 'Floor Tiles', 0.2,
              'Recycling via MRF - Ace Skip Hire', 325, 108.15, 40,
             'Charity - Foodbank Ealing', 360, 99.95, 100,
             0, 325, 8.2, 360, -35, 7.38, 0, '', -26.24, 390.8, -65.8,
             4.1, 325, 0, 0, 0, '', '', 360, -35, 7.38, 0, '', '']

add_row(ISG_UB69PF)

# %%
df.date = pd.to_datetime(df.date, infer_datetime_format=True)
df.replace('', np.nan, inplace=True)

# %%
ef = pd.read_excel('emission_factors.xlsx')
ef['PD waste type'].replace(0, np.nan, inplace=True)

# %%
efk = pd.read_excel('emissions_factors_key.xlsx')

# %%
vc = pd.read_excel('vehicle_costings.xlsx')

# %%
restrictions = pd.read_excel('restrictions.xlsx')

# %%
gf = pd.read_excel('gate_fees.xlsx')

# %%
rk = pd.read_excel('recipient_key.xlsx')

# %%
rdb = pd.read_excel('recipient_db.xlsx')

# %%
am = pd.read_excel('acceptance_materials.xlsx')

# %%
eftp = pd.read_excel('ef_treatment_processes.xlsx')

# %%
efro = pd.read_excel('ef_recycling_offset.xlsx')

# %%
df.to_csv("bluebox_mdf", index=False)
ef.to_csv('emissions_factors.csv', index=False)
efk.to_csv('emissions_factors_key.csv', index=False)
vc.to_csv('vehicle_costings_by material).csv', index=False)
restrictions.to_csv('restrictions.csv', index=False)
gf.to_csv('gate_fees.csv', index=False)
rk.to_csv('recipient_key.csv', index=False)
am.to_csv('acceptance_materials.csv', index=False)
eftp.to_csv('ef_treatment_processes.csv', index=False)
efro.to_csv('ef_recycling_offset.csv', index=False)
